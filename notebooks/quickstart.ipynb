# %% [markdown]
# # Quick start (library)
#
# Prefer the CLI for full training and artifacts: `python -m ev_charging train --config configs/default.yaml`.
#
# Below: load config and build train/test arrays from the packaged pipeline.

# %%
from pathlib import Path

from ev_charging.config import load_config
from ev_charging.pipeline import build_train_test_arrays

root = Path("..").resolve()
cfg = load_config(root / "configs/default.yaml")
pre, X_train, y_train, X_test, y_test, Xm, ym, Xv, yv, _ = build_train_test_arrays(cfg, root)
X_train.shape, y_train.shape, X_test.shape
